# %%
import pandas as pd

# %%
df = pd.read_csv("trending_youtube.csv")

# %%
df.shape
# Out:
# (115, 17)

# %%
print(df.head(10))
# Out:
#    Unnamed: 0                 channelId              channelTitle  \
# 0           0  UCU1_l0ZJyTK_7HZZ3Ruw8Dg                      MAPS
# 1           1  UCLuO2lUqHrPIIpx0hFenV2g            Tink Tink Club
# 2           2  UCihqrkaOgVMfLNo2W1hSliA              Podcast Bunk
# 3           3  UCgbWWPn3VYYzxjffZbfj9GQ           Alan Springwind
# 4           4  UCFmLi6X1mojkFZOFngNR9tQ     Drug Education Agency
# 5           5  UCxSbJSgLqIO8r7TONBN5dvw  Oracle Frequency Podcast
# 6           6  UCSqJniChpE6ngCRzUvNNgug       Fabian-ji Chononita
# 7           7  UCmrLCXSDScliR7q8AxxjvXg       Black Pigeon Speaks
# 8           8  UC2nzGL6I-SRc_gkBLWLDVWg             ellie pipkins
# 9           9  UCn8V3KNSgDr1Dai77_y8JrQ          PsychedSubstance
#
#        videoId               publishedAt  \
# 0  pTnk3ziVVRM  2014-01-10T01:24:57.000Z
# 1  cuJjSeHZIrg  2015-06-18T16:56:04.000Z
# 2  IuyuZfWtGgg  2016-05-01T05:33:13.000Z
# 3  cng_ZhQf8iY  2016-01-25T04:48:22.000Z
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  videoCategoryId  durationSec      viewCount    likeCount  \
# count  115.000000       115.000000   115.000000     115.000000   111.000000
# mean    57.000000        24.417391   402.504348    9164.052174   172.414414
# std     33.341666         4.163295   687.782228   52011.249730   856.646490
# min      0.000000         1.000000     1.000000       2.000000     0.000000
# 25%     28.500000        22.000000    95.000000     128.500000     0.000000
# 50%     57.000000        24.000000   220.000000     356.000000     2.000000
# 75%     85.500000        28.000000   473.500000    1153.500000    13.000000
# max    114.000000        29.000000  4780.000000  526243.000000  7046.000000
#
#        dislikeCount  commentCount
# count    111.000000    113.000000
# mean      14.207207     77.097345
# std       97.505722    398.256243
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        1.000000      9.000000
# ...
